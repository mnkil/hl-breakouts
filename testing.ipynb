# %% [markdown]
# # Testing

# %%
import bomy

# %%
df = bomy.ret_binance_spot('BTCUSDT', '1H', '2024-01-01')
# Out:
# 2024-10-22 19:10:47: bomyPandas init...
# 2024-10-22 19:10:47:  <class 'pandas.core.frame.DataFrame'>
# 2024-10-22 19:10:47: bomyPandas columns -->
# ---------------------------------------
# index: int64
# Open Time: datetime64[ns]
# Open: float64
# High: float64
# Low: float64
# Close: float64
# Volume: float64
# Close Time: datetime64[ns]
# Quote Asset Volume: object
# Number of Trades: int64
# Taker Buy Base Asset Volume: object
# Taker Buy Quote Asset Volume: object
# Ignore: object
# ts_date: datetime64[ns]
# ---------------------------------------
# 2024-10-22 19:10:47: bomyPandas done...

# %%
df
# Out:
#       index           Open Time      Open      High       Low     Close  \
# 0         0 2024-01-01 00:00:00  42283.58  42554.57  42261.02  42475.23
# 1         1 2024-01-01 01:00:00  42475.23  42775.00  42431.65  42613.56
# 2         2 2024-01-01 02:00:00  42613.57  42638.41  42500.00  42581.10
# 3         3 2024-01-01 03:00:00  42581.09  42586.64  42230.08  42330.49
# 4         4 2024-01-01 04:00:00  42330.50  42399.99  42209.46  42399.99
# ...     ...                 ...       ...       ...       ...       ...
# 7052   7052 2024-10-20 20:00:00  68508.30  68900.00  68461.93  68781.98
# 7053   7053 2024-10-20 21:00:00  68781.98  68870.00  68658.00  68770.00
# 7054   7054 2024-10-20 22:00:00  68770.00  69400.00  68600.00  69137.28
# 7055   7055 2024-10-20 23:00:00  69137.28  69196.16  68923.32  69031.99
# 7056   7056 2024-10-21 00:00:00  69032.00  69519.52  68972.56  69160.00
#
#           Volume              Close Time  Quote Asset Volume  \
# ...
